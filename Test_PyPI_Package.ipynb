# %%
# !pip install Jigglypuff==0.2
# Out:
# ...
#   Created wheel for Jigglypuff: filename=Jigglypuff-0.2-py2.py3-none-any.whl size=6260 sha256=667c0adbc9426270134a6477d11f442e0b8818c521170bc6e5fdf39070449d21
#   Stored in directory: /Users/hana/Library/Caches/pip/wheels/6d/35/f5/aa689f15ca25bc8f6af997b04ae5044fb27343d99c172ef599
# Successfully built Jigglypuff
# ...
#   Attempting uninstall: Jigglypuff
#     Found existing installation: Jigglypuff 0.1
#     Uninstalling Jigglypuff-0.1:
#       Successfully uninstalled Jigglypuff-0.1
# ...

# %%
from Jigglypuff.RiskDataframe import RiskDataframe
import pandas as pd

# %%
dataframe = pd.read_csv("AUTO_LOANS_DATA.csv", sep=";")

# %%
myrdf = RiskDataframe(dataframe)

# %%
myrdf.heatPlot()
